# %% [markdown]
# <a href="https://colab.research.google.com/github/beatricenfodwaa-max/datasci_1_loading/blob/main/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **the **

# %% [markdown]
# ** The following code cell imports pandas and json**
#   we need pandas because we cannot load our dataset without it

# %%
import pandas as pd

import Json

# %%
import pandas as pd

df1 ='/content/data /data1.csv'
read_csv1 = pd.read_csv(df1)
read_csv1.head(11)
# Out:
#    CMS Certification Number (CCN)                    Measure Code  Score  \
# 0                          NATION               I_006_01_NATL_SIR  1.005
# 1                          NATION          I_011_05_NATL_OBS_RATE  64.84
# 2                          NATION          I_012_06_NATL_OBS_RATE  62.03
# 3                          NATION          I_013_01_NATL_OBS_RATE   0.14
# 4                          NATION               I_015_01_NATL_SIR  0.331
# 5                          NATION          I_016_01_NATL_OBS_RATE  77.10
# 6                          NATION   I_017_01_PPR_PD_NATL_OBS_RATE   9.21
# 7                          NATION   I_017_01_PPR_PD_N_BETTER_NATL     19
# 8                          NATION  I_017_01_PPR_PD_N_NO_DIFF_NATL  1,101
# 9                          NATION     I_017_01_PPR_PD_N_TOO_SMALL     19
# 10                         NATION    I_017_01_PPR_PD_N_WORSE_NATL     55
#
#    Footnote  Start Date    End Date Measure Date Range
# ...

# %% [markdown]
# Csv_data1 presents the follwoing:
#
#
# 1. **CMS Certificate Number** Identifies the reporting facility or reporting level. The value `NATION` indicates that the row contains a national result rather than the result of an individual healthcare facility
# 2. **Measure Code** the unique code used to identify the healthcare quality or infection measure being reported.
# 3. **Score:** The national result for the measure. Depending on the measure code, the score may represent a standardized infection ratio, an observed rate, or the number of facilities in a performance category.
# 4. **Footnote:** Provides additional information or qualifications about the reported result. A dash (`-`) indicates that no footnote was provided.
# 5. **Start Date:** The beginning of the period during which data for the measure were collected.
# 6. **End Date:** The end of the period during which data for the measure were collected.
# 7. **Measure Date Range:** Provides a combined or additional description of the measurement period when available. A dash (`-`) indicates that no additional date range was reported.
#
# **what the code do?**
# we need this code so that pandas can read the csv dataset.

# %%
import pandas as pd
df2 = '/content/data /data2.csv'

read_csv2 = pd.read_csv(df2)
read_csv2.head(11)
# Out:
#    GHO (CODE)                                      GHO (DISPLAY)  \
# 0    WHS6_102              Hospital beds (per 10 000 population)
# 1   DEVICES05  Total density per 100 000 population: Speciali...
# 2   DEVICES01  Total density per 100 000 population: Health p...
# 3   DEVICES05  Total density per 100 000 population: Speciali...
# 4   DEVICES04  Total density per 100 000 population: Provinci...
# 5   DEVICES02  Total density per 100 000 population: Health c...
# 6   DEVICES02  Total density per 100 000 population: Health c...
# 7   DEVICES00    Total density per 100 000 population: Hospitals
# 8   DEVICES03  Total density per 100 000 population: District...
# 9   DEVICES04  Total density per 100 000 population: Provinci...
# 10   WHS6_102              Hospital beds (per 10 000 population)
#
#                                             GHO (URL)  YEAR (DISPLAY)  \
# 0   https://www.who.int/data/gho/data/indicators/i...            2010
# ...

# %% [markdown]
# WHO Global Health Observatory Dataset Features
#
# - **GHO (CODE):** The identification code assigned by the World Health Organization to each health indicator.
# - **GHO (DISPLAY):** The name or description of the health indicator being measured.
# - **GHO (URL):** A link to the WHO webpage containing information about the indicator.
# - **YEAR (DISPLAY):** The year associated with the reported result.
# - **STARTYEAR:** The first year of the measurement period.
# - **ENDYEAR:** The last year of the measurement period.
# - **REGION (CODE):** The abbreviated WHO code for the geographic region. For example, `AFR` represents Africa.
# - **REGION (DISPLAY):** The complete name of the WHO geographic region.
# - **COUNTRY (CODE):** The three-letter code used to identify the country. For example, `ZMB` represents Zambia.
# - **COUNTRY (DISPLAY):** The complete name of the country.
# - **DIMENSION (TYPE):** The type of additional category used to separate the data, when applicable.
# - **DIMENSION (CODE):** The code assigned to an additional data category, when applicable.
# - **DIMENSION (NAME):** The name of the additional data category, when applicable.
# - **Numeric:** The complete numerical result for the health indicator.
# - **Value:** The displayed or rounded version of the numerical result.
# - **Low:** The lower limit of the estimated result, when available.
# - **High:** The upper limit of the estimated result, when available.
#
# **Note:** `NaN` means that a value is missing or was not provided. The numbers shown on the far left are row indexes and are not dataset features.

# %%
import pandas as pd
df3 ='/content/Financial Sample.xlsx'

read_xlsx1 = pd.read_excel(df3)
read_xlsx1.head(11)
# Out:
#              Segment  Country    Product Discount Band  Units Sold  \
# 0         Government   Canada  Carretera           NaN      1618.5
# 1         Government  Germany  Carretera           NaN      1321.0
# 2          Midmarket   France  Carretera           NaN      2178.0
# 3          Midmarket  Germany  Carretera           NaN       888.0
# 4          Midmarket   Mexico  Carretera           NaN      2470.0
# 5         Government  Germany  Carretera           NaN      1513.0
# 6          Midmarket  Germany    Montana           NaN       921.0
# 7   Channel Partners   Canada    Montana           NaN      2518.0
# 8         Government   France    Montana           NaN      1899.0
# 9   Channel Partners  Germany    Montana           NaN      1545.0
# 10         Midmarket   Mexico    Montana           NaN      2470.0
#
#     Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                     3          20      32370.0        0.0   32370.0
# ...

# %% [markdown]
# Customer Purchase Dataset Features
#
# - **CUST_NAME:** Customer’s name.
# - **Gender_Code:** Customer’s gender or title.
# - **ADDRESS1 and ADDRESS2:** Customer’s street address.
# - **CITY, STATE, and COUNTRY_CODE:** Customer’s geographic location.
# - **POSTAL_CODE and POSTAL_CODE_PLUS4:** Customer’s postal information.
# - **EMAIL_ADDRESS:** Customer’s email address.
# - **Product category columns:** Indicate whether the customer purchased from each category; `1` means yes and `0` means no.
# - **NaN:** Indicates missing information.

# %%
import pandas as pd
df4 = '/content/data /supplier-diversity-regional-plan-2023_10202025.xlsx'

read_xlsx2 = pd.read_excel(df4)
read_xlsx2.head(11)
# Out:
#     Hospital_Region_ID                             Region_Name  \
# 0                    4                          Palomar Health
# 1                   11                        John Muir Health
# 2                    1            Adventist Health System/West
# 3                    8          Sharp HealthCare System Report
# 4                    3                    Keck Medicine of USC
# 5                   12  MARIAN REGIONAL MEDICAL CENTER - GROUP
# 6                   13    MERCY HOSPITAL - BAKERSFIELD - GROUP
# 7                   18        Community Memorial Health System
# 8                    2                   Alameda Health System
# 9                    7                                 Scripps
# 10                   6                     Providence - All CA
#
#                                  Associated_Hospitals  \
# 0                                 106370977,106374382
# 1                       106070988,106071018,106074039
# ...

# %% [markdown]
# Hospital Procurement Dataset Features
#
# - **Hospital_Region_ID:** Unique number assigned to the hospital region.
# - **Region_Name:** Name of the hospital or healthcare region.
# - **Associated_Hospitals:** Identification numbers of hospitals included in the report.
# - **System_Reporting_Organization:** Organization that submitted the report.
# - **System_Description:** Description of the healthcare system and reported data.
# - **System_Report_Start_Date:** Beginning of the reporting period.
# - **System_Report_End_Date:** End of the reporting period.
# - **System_Require_Certification:** Indicates whether certification is required.
# - **System_Self_Certification:** Indicates whether the organization certified its own report.
# - **System_Tier_I_African_American:** Tier I spending with African American-owned suppliers.
# - **System_Tier_II_Disabled_Veteran:** Tier II spending with disabled veteran-owned suppliers.
# - **System_Total_Disabled_Veteran:** Total spending with disabled veteran-owned suppliers.
# - **System_Tier_I_Less_Duplicated_Amount:** Tier I spending after removing duplicated amounts.
# - **System_Tier_II_Less_Duplicated_Amount:** Tier II spending after removing duplicated amounts.
# - **System_Total_Less_Duplicated_Amount:** Total spending after removing duplicated amounts.
# - **System_Combined_Tier_I_Total:** Total Tier I procurement spending.
# - **System_Combined_Tier_II_Total:** Total Tier II procurement spending.
# - **System_Combined_Total:** Combined Tier I and Tier II spending.
# - **System_Total_Hospital_Procurement:** Total procurement spending reported by the hospital system.
# - **System_Other_Relevant_Info:** Additional information supplied by the organization.
# - **NaN:** Indicates missing or unreported information.

# %%
import pandas as pd
df5 = '/content/data /supplier-diversity-plan-2022-extract.xlsx'

read_xslx3 = pd.read_excel(df5)
read_xslx3.head(11)
# Out:
#                                       Hospital_Name  \
# 0              RADY CHILDREN'S HOSPITAL - SAN DIEGO
# 1          UCSF BENIOFF CHILDREN'S HOSPITAL OAKLAND
# 2   CITY OF HOPE HELFORD CLINICAL RESEARCH HOSPITAL
# 3                CHILDREN'S HOSPITAL OF LOS ANGELES
# 4             HOLLYWOOD PRESBYTERIAN MEDICAL CENTER
# 5                  PORTERVILLE DEVELOPMENTAL CENTER
# 6   SHRINERS HOSPITALS FOR CHILDREN NORTHERN CALIF.
# 7                      PALOMAR MEDICAL CENTER POWAY
# 8                       BARLOW RESPIRATORY HOSPITAL
# 9      COMMUNITY HOSPITAL OF THE MONTEREY PENINSULA
# 10                  STANFORD HEALTH CARE TRI-VALLEY
#
#                                      Hospital_Address    HCAI_ID  \
# 0            3020 CHILDREN'S WAY, SAN DIEGO, CA 92123  106370673
# 1                  747 52ND STREET, OAKLAND, CA 94609  106010776
# 2                  1500 DUARTE ROAD, DUARTE, CA 91010  106190176
# 3     4650 W. SUNSET BOULEVARD, LOS ANGELES, CA 90027  106190170
# ...

# %% [markdown]
# Hospital Procurement Dataset Features
#
# - **Hospital_Name:** Name of the hospital.
# - **Hospital_Address:** Hospital’s business address.
# - **HCAI_ID:** Identification number assigned to the hospital by HCAI.
# - **License_Number:** California-issued hospital license number.
# - **Licensee:** Organization that holds the hospital’s license.
# - **Type_Control:** Hospital’s ownership or control type.
# - **County:** County where the hospital is located.
# - **MSSA:** Hospital’s Medical Service Study Area.
# - **HSA:** Hospital’s Health Service Area.
# - **HFPA:** Hospital’s Health Facility Planning Area.
# - **Combined_Total:** Total spending with diverse suppliers.
# - **Total_Hospital_Procurement:** Hospital’s total procurement spending.
# - **Contact_Name:** Name of the hospital’s supplier contact.
# - **Contact_Email:** Email address of the supplier contact.
# - **Contact_Phone_Number:** Phone number of the supplier contact.
# - **Website_Link:** Hospital’s supplier or procurement website.
# - **Third_Party:** Indicates whether a third-party procurement company is used.
# - **Third_Party_Name:** Name of the third-party procurement company.
# - **Third_Party_Website:** Website of the third-party company.
# - **Other_Relevant_Info:** Additional information provided by the hospital.

# %%
import json
df6 ='/content/budgets.json'

read_json = pd.read_json(df6)
read_json.head(11)
# Out:
#     budgetYear  forecastYear  value
# 0         1980          1980 -0.103
# 1         1980          1981 -0.037
# 2         1980          1982  0.010
# 3         1980          1983  0.051
# 4         1981          1980 -0.192
# 5         1981          1981 -0.129
# 6         1981          1982 -0.060
# 7         1981          1983 -0.017
# 8         1981          1984  0.063
# 9         1982          1981 -0.185
# 10        1982          1982 -0.215

# %% [markdown]
# Federal Budget Dataset Features
#
# - **budgetYear:** The year when the budget projection was created.
# - **forecastYear:** The year covered by the projection.
# - **value:** The projected or actual federal budget result in trillions of dollars. Negative values represent deficits, while positive values represent surpluses.

# %%
import json
df7 = '/content/cars.json'

read_json = pd.read_json(df7)
read_json.head(11)
# Out:
#                          Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0   chevrolet chevelle malibu              18.0          8         307.0
# 1           buick skylark 320              15.0          8         350.0
# 2          plymouth satellite              18.0          8         318.0
# 3               amc rebel sst              16.0          8         304.0
# 4                 ford torino              17.0          8         302.0
# 5            ford galaxie 500              15.0          8         429.0
# 6            chevrolet impala              14.0          8         454.0
# 7           plymouth fury iii              14.0          8         440.0
# 8            pontiac catalina              14.0          8         455.0
# 9          amc ambassador dpl              15.0          8         390.0
# 10       citroen ds-21 pallas               NaN          4         133.0
#
#     Horsepower  Weight_in_lbs  Acceleration        Year  Origin
# ...

# %% [markdown]
# Automobile Dataset Features
#
# - **Name:** Make and model of the vehicle.
# - **Miles_per_Gallon:** Vehicle’s estimated fuel efficiency in miles per gallon.
# - **Cylinders:** Number of engine cylinders.
# - **Displacement:** Engine displacement measured in cubic inches.
# - **Horsepower:** Engine power measured in horsepower.
# - **Weight_in_lbs:** Vehicle weight measured in pounds.
# - **Acceleration:** Time required to accelerate from 0 to 60 miles per hour, measured in seconds.
# - **Year:** Vehicle’s model year.
# - **Origin:** Region where the vehicle was manufactured.

# %%
import json
df8 = '/content/crimea.json'

read_json = pd.read_json(df8)
read_json.head(11)
# Out:
#          date  wounds  other  disease  army_size
# 0  1854-04-01       0      5        1       8571
# 1  1854-05-01       0      9       12      23333
# 2  1854-06-01       0      6       11      28333
# 3  1854-07-01       0     23      359      28722
# 4  1854-08-01       1     30      828      30246
# 5  1854-09-01      81     70      788      30290
# 6  1854-10-01     132    128      503      30643
# 7  1854-11-01     287    106      844      29736
# 8  1854-12-01     114    131     1725      32779
# 9  1855-01-01      83    324     2761      32393
# 10 1855-02-01      42    361     2120      30919

# %% [markdown]
# Crimean War Mortality Dataset Features
#
# - **date:** Month and year when the information was recorded.
# - **wounds:** Number of deaths caused by wounds and injuries.
# - **other:** Number of deaths caused by other conditions.
# - **disease:** Number of deaths caused by preventable infectious diseases.
# - **army_size:** Estimated average number of soldiers in the army during that month.
